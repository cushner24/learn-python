# %%
import pandas as pd

url1 = 'https://www.cbssports.com/mlb/standings/'
data = pd.read_html(url1)
standings = data[0]
columns = standings.iloc[0].tolist()
columns[0]='Team'
standings.columns = columns
x = standings[standings['Day'] != 'Day']
x.sort_values('L  Losses', ascending=False)
# Out:
#               Team W  Wins L  Losses PCT  Win Percentage GB  Games behind  \
# 5        Baltimore      23        56                .291             30.0
# 11     Kansas City      25        55                .313             19.5
# 10  Chi. White Sox      28        51                .354             16.0
# 17           Texas      36        46                .439             18.0
# 9          Detroit      36        45                .444              9.0
# 4          Toronto      37        43                .463             16.5
# 8        Minnesota      34        42                .447              8.5
# 3        Tampa Bay      39        40                .494             14.0
# 16     L.A. Angels      41        40                .506             12.5
# 15         Oakland      43        38                .531             10.5
# 7        Cleveland      44        35                .557                —
# 14         Seattle      50        31                .617              3.5
# ...
